# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from skimage import io, measure

# %%
matang = 'images/matang - 1.jpg'
mentah = 'images/mentah - 3.jpg'

# %%
# img = io.imread(matang)
img = io.imread(mentah)
plt.imshow(img)

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
# mask = cv2.inRange(hsv, (10, 100, 59), (30, 150, 250))
mask = cv2.inRange(hsv, (10, 150, 125), (30, 250, 250))
plt.imshow(mask)
